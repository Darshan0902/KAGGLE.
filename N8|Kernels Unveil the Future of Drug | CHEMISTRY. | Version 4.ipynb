# %% [markdown]
# <a href="https://www.kaggle.com/code/darshanprabhu09/n8-kernels-unveil-the-future-of-drug-chemistry?scriptVersionId=135685810" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# ## <span style="color: #FF4500;"> 1.)IMPORTING LIBRARIES </span>
# <p style="padding: 10px; background-color: #000000; margin: 0; color: #FF4500; font-family: New Times Roman; font-size: 135%; text-align: center; border-radius: 5px; overflow: hidden; font-weight: 500;">
#                      STEP-1:<br>
#    Importing the essential  Libraries we are gonna use.
# </p>
#
#
# <p style="text-align: center;">
#     The import statement is used to bring in the libraries into your Python program. numpy is typically imported as np, and pandas is commonly imported as pd. These libraries are widely used for data manipulation, analysis, and processing in Python.
# </p>

# %%
#For data manupilation and exploratory data analysis.
import pandas as pd 

#For converting data ins=to Matrices.
import numpy as np

#For the purpose of data visualization and plotting graphs  
import matplotlib.pyplot as plt

#Importing sklearn to use it various models.
import sklearn

# %% [markdown]
# ## <span style="color: #FF4500;"> SKlearn libraries </span>

# %%
#For splitting the data into Training and Testing datasets.
from sklearn.model_selection import train_test_split

#For implementing the Linear Regression model.
from sklearn.linear_model import LinearRegression 

#For using the Random forsest regression model 
from sklearn.ensemble import RandomForestRegressor 

#For checking the fitting and evaluating our model.
from sklearn.metrics import mean_squared_error , r2_score

# %% [markdown]
# ## <span style="color: #FF4500;"> 2.) DATA COLLECTION</span>
# <p style="padding: 10px; background-color: #000000; margin: 0; color: #FF4500; font-family: New Times Roman; font-size: 135%; text-align: center; border-radius: 5px; overflow: hidden; font-weight: 500;">
#                      STEP-2:<br>
#   Data Collection and Data Preparation .
# </p>
#
# <p style="text-align: center;">
#    We did break data into "Training set" and "Testing set" for the purpose of training our model and later on for the evaluation of the model.
# </p>

# %% [markdown]
# ## <span style="color: #FF4500;"> LOADING THE DATASET </span>

# %%
df = pd.read_csv("/kaggle/input/delaney-solubility-with-descriptors/delaney_solubility_with_descriptors.csv")

# %% [markdown]
# ## <span style="color: #FF4500;"> DATA PREPARATION. </span>

# %% [markdown]
# ## <span style="color: #FF4500;"> 1- DEFINING INDEPENDENT AND DEPENDENT VARIABLES: </span>
#
# X = INDEPENDENT OR THE TARGET VARIABLE. <BR>
# Y = DEPENDENT OR PREDICTOR VARIABLE.

# %%
y = df["logS"]
y #The dependent variable.
# Out:
# 0      -2.180
# 1      -2.000
# 2      -1.740
# 3      -1.480
# 4      -3.040
#         ...
# 1139    1.144
# 1140   -4.925
# 1141   -3.893
# 1142   -3.790
# 1143   -2.581
# Name: logS, Length: 1144, dtype: float64

# %%
x = df.drop("logS",axis = 1)
x #The independent variable.
# Out:
#       MolLogP    MolWt  NumRotatableBonds  AromaticProportion
# 0     2.59540  167.850                0.0            0.000000
# 1     2.37650  133.405                0.0            0.000000
# 2     2.59380  167.850                1.0            0.000000
# 3     2.02890  133.405                1.0            0.000000
# 4     2.91890  187.375                1.0            0.000000
# ...       ...      ...                ...                 ...
# 1139  1.98820  287.343                8.0            0.000000
# 1140  3.42130  286.114                2.0            0.333333
# 1141  3.60960  308.333                4.0            0.695652
# 1142  2.56214  354.815                3.0            0.521739
# 1143  2.02164  179.219                1.0            0.461538
#
# [1144 rows x 4 columns]

# %% [markdown]
# ## <span style="color: #FF4500;"> Splitting the datasets into Training and Testing data : </span>
# ### In this case we will be dividing and keeping the Training dataset as 80%(0.8) and the remaining Testing data as 20%(0.2).

# %%
x_train , x_test  = train_test_split(x,train_size = 0.8 , random_state = 100)

# %%
y_train,y_test = train_test_split(y,train_size = 0.8,random_state = 100)

# %% [markdown]
# ## <span style="color: #FF4500;"> Checking the datasets of Training and Testing data : </span>
# ![image.png](attachment:78d78f5d-b58a-4254-a2ff-e05527c2fbfa.png)

# %% [markdown]
# ## <span style="color: #FF4500;"> Training data </span>

# %%
x_train
# Out:
#      MolLogP    MolWt  NumRotatableBonds  AromaticProportion
# 107  3.14280  112.216                5.0            0.000000
# 378 -2.07850  142.070                0.0            0.000000
# 529 -0.47730  168.152                0.0            0.000000
# 546 -0.86740  154.125                0.0            0.000000
# 320  1.62150  100.161                2.0            0.000000
# ..       ...      ...                ...                 ...
# 802  3.00254  250.301                1.0            0.842105
# 53   2.13860   82.146                3.0            0.000000
# 350  5.76304  256.348                0.0            0.900000
# 79   3.89960  186.339               10.0            0.000000
# 792  2.52334  310.297                3.0            0.300000
#
# [915 rows x 4 columns]

# %%
y_train
# Out:
# 107   -4.440
# 378   -1.250
# 529   -1.655
# 546   -1.886
# 320   -0.740
#        ...
# 802   -2.925
# 53    -2.680
# 350   -7.020
# 79    -4.800
# 792   -3.240
# Name: logS, Length: 915, dtype: float64

# %% [markdown]
# ## <span style="color: #FF4500;"> Testing data </span>

# %%
x_test
# Out:
#       MolLogP    MolWt  NumRotatableBonds  AromaticProportion
# 822   2.91000  172.268                7.0            0.000000
# 118   7.27400  360.882                1.0            0.666667
# 347   1.94040  145.161                0.0            0.909091
# 1123  1.98640  119.378                0.0            0.000000
# 924   1.70062  108.140                0.0            0.750000
# ...       ...      ...                ...                 ...
# 1114  1.76210  478.513                4.0            0.000000
# 427   6.32820  276.338                0.0            1.000000
# 711   0.04430  218.205                5.0            0.000000
# 4     2.91890  187.375                1.0            0.000000
# 948   3.56010  318.328                2.0            0.750000
#
# [229 rows x 4 columns]

# %%
y_test
# Out:
# 822    -3.380
# 118    -8.010
# 347    -2.160
# 1123   -1.170
# 924    -0.730
#         ...
# 1114   -4.130
# 427    -9.018
# 711    -0.600
# 4      -3.040
# 948    -2.900
# Name: logS, Length: 229, dtype: float64

# %% [markdown]
# ## <span style="color: #FF4500;"> 3.) EXPLORATORY DATA ANALYSIS </span>
# <p style="padding: 10px; background-color: #000000; margin: 0; color: #FF4500; font-family: New Times Roman; font-size: 135%; text-align: center; border-radius: 5px; overflow: hidden; font-weight: 500;">
#                      STEP-3:<br>
#  Exploratory Data Analysis .
# </p>
#
# <p style="text-align: center;">
#
# Exploratory Data Analysis (EDA) is a crucial step in the data analysis process. It involves examining and understanding the dataset to gain insights, discover patterns, and identify potential issues or relationships within the data
# </p>

# %% [markdown]
# ## <span style="color: #FF4500;"> 3.1  DataFrame.head(): </span>
# #### Returns the first  rows of a DataFrame.

# %%
df.head()
# Out:
#    MolLogP    MolWt  NumRotatableBonds  AromaticProportion  logS
# 0   2.5954  167.850                0.0                 0.0 -2.18
# 1   2.3765  133.405                0.0                 0.0 -2.00
# 2   2.5938  167.850                1.0                 0.0 -1.74
# 3   2.0289  133.405                1.0                 0.0 -1.48
# 4   2.9189  187.375                1.0                 0.0 -3.04

# %% [markdown]
# ## <span style="color: #FF4500;"> 3.2  DataFrame.tail(): </span>
# #### Returns the last rows of a DataFrame.

# %%
df.tail()
# Out:
#       MolLogP    MolWt  NumRotatableBonds  AromaticProportion   logS
# 1139  1.98820  287.343                8.0            0.000000  1.144
# 1140  3.42130  286.114                2.0            0.333333 -4.925
# 1141  3.60960  308.333                4.0            0.695652 -3.893
# 1142  2.56214  354.815                3.0            0.521739 -3.790
# 1143  2.02164  179.219                1.0            0.461538 -2.581

# %% [markdown]
# ## <span style="color: #FF4500;"> 3.3 DataFrame.isnull(): </span>
# #### Returns a DataFrame of the same shape as the original, with True in locations where null values are present and False otherwise.

# %%
df.isnull()
# Out:
#       MolLogP  MolWt  NumRotatableBonds  AromaticProportion   logS
# 0       False  False              False               False  False
# 1       False  False              False               False  False
# 2       False  False              False               False  False
# 3       False  False              False               False  False
# 4       False  False              False               False  False
# ...       ...    ...                ...                 ...    ...
# 1139    False  False              False               False  False
# 1140    False  False              False               False  False
# 1141    False  False              False               False  False
# 1142    False  False              False               False  False
# 1143    False  False              False               False  False
#
# [1144 rows x 5 columns]

# %% [markdown]
# ## <span style="color: #FF4500;"> 3.4 DataFrame.describe(): </span>
# #### Generates descriptive statistics of numerical columns in the DataFrame, such as count, mean, min, max, etc.

# %%
df.describe()
# Out:
#            MolLogP        MolWt  NumRotatableBonds  AromaticProportion  \
# count  1144.000000  1144.000000        1144.000000         1144.000000
# mean      2.449133   204.631675           2.173951            0.364932
# std       1.866003   102.620500           2.627398            0.343305
# min      -7.571400    16.043000           0.000000            0.000000
# 25%       1.414900   122.126000           0.000000            0.000000
# 50%       2.340300   183.594500           1.000000            0.375000
# 75%       3.406475   270.715750           3.000000            0.666667
# max      10.388600   780.949000          23.000000            1.000000
#
#               logS
# count  1144.000000
# mean     -3.057997
# std       2.096502
# min     -11.600000
# 25%      -4.332250
# 50%      -2.870500
# 75%      -1.600000
# max       1.580000

# %% [markdown]
# ## <span style="color: #FF4500;"> 3.5 DataFrame.shape: </span>
# #### Returns the dimensions (rows, columns) of the DataFrame.

# %%
df.shape
# Out:
# (1144, 5)

# %% [markdown]
# ## <span style="color: #FF4500;"> 3.6 DataFrame.info(): </span>
# #### Provides a summary of the DataFrame, including column names, data types, and non-null counts.

# %%
df.info
# Out:
# <bound method DataFrame.info of       MolLogP    MolWt  NumRotatableBonds  AromaticProportion   logS
# 0     2.59540  167.850                0.0            0.000000 -2.180
# 1     2.37650  133.405                0.0            0.000000 -2.000
# 2     2.59380  167.850                1.0            0.000000 -1.740
# 3     2.02890  133.405                1.0            0.000000 -1.480
# 4     2.91890  187.375                1.0            0.000000 -3.040
# ...       ...      ...                ...                 ...    ...
# 1139  1.98820  287.343                8.0            0.000000  1.144
# 1140  3.42130  286.114                2.0            0.333333 -4.925
# 1141  3.60960  308.333                4.0            0.695652 -3.893
# 1142  2.56214  354.815                3.0            0.521739 -3.790
# 1143  2.02164  179.219                1.0            0.461538 -2.581
#
# [1144 rows x 5 columns]>

# %% [markdown]
# ## <span style="color: #FF4500;"> 4.7 DataFrame.dtypes():</span>
# #### Returns the data types of each column in the DataFrame.

# %%
df.dtypes
# Out:
# MolLogP               float64
# MolWt                 float64
# NumRotatableBonds     float64
# AromaticProportion    float64
# logS                  float64
# dtype: object

# %% [markdown]
# ## <span style="color: #FF4500;"> Checking the size of our Training and Testing data : </span>

# %%
x1= x_train.shape 
y1 = y_train.shape

print("The training size for dataset of X = {} and for Y it is gonna be {} where rows ".format(x1,y1))
# Out:
# The training size for dataset of X = (915, 4) and for Y it is gonna be (915,) where rows

# %%
x2= x_test.shape 
y2 = y_test.shape

print("The testing size for dataset of X = {} and for Y it is gonna be {}".format(x2,y2))
# Out:
# The testing size for dataset of X = (229, 4) and for Y it is gonna be (229,)

# %% [markdown]
# ## <span style="color: #FF4500;"> 4.) MODEL BUILDING :  </span>
# <p style="padding: 10px; background-color: #000000; margin: 0; color: #FF4500; font-family: New Times Roman; font-size: 135%; text-align: center; border-radius: 5px; overflow: hidden; font-weight: 500;">
#                      STEP-4:<br>
#  Model Building using Pipeline .
# </p>
#
# <p style="text-align: center;">

# %% [markdown]
# ## <span style="color: #FF4500;"> 1.) LINEAR REGRESSION MODEL: </span>

# %% [markdown]
# #### <span style="color: #FF4500;"> Training the model</span>

# %%
lr = LinearRegression()
lr.fit(x_train , y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## <span style="color: #FF4500;"> 4.1 : Random Forest Regressor model. </span>

# %% [markdown]
# #### <span style="color: #FF4500;"> Training the model </span>

# %%
rfr = RandomForestRegressor(max_depth = 2 , random_state = 100)
rfr.fit(x_train,y_train)
# Out:
# RandomForestRegressor(max_depth=2, random_state=100)

# %% [markdown]
# ## <span style="color: #FF4500;"> 5.) PREDICTION. </span>
# <p style="padding: 10px; background-color: #000000; margin: 0; color: #FF4500; font-family: New Times Roman; font-size: 135%; text-align: center; border-radius: 5px; overflow: hidden; font-weight: 500;">
#                      STEP-5: PREDICTION.<br>
#
# </p>
#
# <p style="text-align: center;">

# %% [markdown]
# ## <span style="color: #FF4500;"> 5.1 : Linear regression model prediction:</span>

# %% [markdown]
# Since we already know Y is a dependent variable that depends on value of the independent variable X so in form of statistics it can be represented as ;
#
# Y =F(X)

# %% [markdown]
# ## LR TRAINING DATA

# %%
y_lr_pred_train = lr.predict(x_train)
print(y_lr_pred_train)

#Prediction for the train or the 80% of data.
# Out:
# [-2.83668969  0.84208401 -0.50930302 -0.13058053 -1.6269208  -2.86103037
#  -2.32208333 -4.16684323 -5.04235077 -2.29737009 -3.15082845 -4.33037208
#  -1.43700682 -2.59060064 -7.09025955 -2.32734557 -4.19073421 -2.63904005
#  -3.58104074 -3.75929058 -2.5501665  -3.26968347 -2.78911367 -2.69251051
#  -0.77437547 -6.61955792 -2.99084623 -2.36975061 -7.18167736 -1.52816491
#  -4.81736265 -0.86996608 -7.09025955 -1.87404275 -2.58013247 -4.80953284
#  -4.17454084 -1.95444152 -3.50503339 -2.7411418  -1.87131835 -2.45270806
#  -3.07252433 -1.48988982 -3.98778754 -1.35216679 -0.16932277 -6.05237002
#  -3.29550658  0.30513174 -3.25501463 -5.31993586 -0.4733928  -4.79180882
#  -5.82486323 -2.70343539 -3.70838271 -2.4987341  -2.12301018 -3.11393974
#  -2.79842053 -1.38274662 -4.3267103  -3.57778946 -3.42356884 -9.15826626
#  -6.52588866 -1.75832085 -4.97842312 -1.59255758 -1.91317252 -2.81075595
#  -1.14056747 -1.6326702  -1.6269208  -5.33227425 -3.88805074  0.70432882
# ...

# %% [markdown]
# ## TESTING DATA OF LR

# %%
y_lr_pred_test = lr.predict(x_test)
y_lr_pred_test
# Prediction for the test or remaining 20% of data.
# Out:
# array([-3.05722870e+00, -7.77785827e+00, -2.55016650e+00, -2.01523582e+00,
#        -2.06375990e+00, -9.99672215e-01, -5.94603364e-01, -5.53626003e-01,
#        -5.72200956e+00, -3.94006681e+00, -3.95496755e+00, -2.29737009e+00,
#        -1.48980354e+00, -1.48988982e+00, -4.64510806e+00, -1.90396018e+00,
#        -1.51566313e+00, -3.16424605e+00, -3.70863920e+00, -5.58105660e+00,
#        -3.25038467e+00, -5.04235077e+00, -5.69194881e+00, -2.14339849e+00,
#        -4.35689341e+00, -5.03964756e+00, -3.10383618e+00, -4.40286964e+00,
#        -4.21276272e+00,  5.56508349e-01, -1.45537678e+00, -4.41027396e+00,
#        -2.59668773e+00, -1.53336276e+00, -5.55749874e-01, -1.67111795e+00,
#        -2.78163675e+00, -3.15395565e+00, -5.27083361e+00, -1.75321446e+00,
#        -1.53350725e+00, -2.01255666e+00, -6.57559167e+00, -7.89433046e+00,
#        -5.76437127e+00, -4.16422068e+00, -3.43694663e+00,  1.43834212e+00,
# ...

# %% [markdown]
# ## <span style="color: #FF4500;"> 5.2 : Random Forest Regressor model prediction: </span>

# %% [markdown]
# ## Randomforest Training data

# %%
y_rfr_train_pred = rfr.predict(x_train)
y_rfr_train_pred
# Out:
# array([-4.44388581, -1.40132433, -1.41481453, -1.41481453, -1.44411435,
#        -2.67492782, -2.50755276, -3.95611327, -4.62529592, -2.27343298,
#        -2.69241199, -4.5150244 , -1.41481453, -2.67492782, -7.14501987,
#        -2.30422396, -4.0676017 , -3.36086239, -2.53282364, -4.5150244 ,
#        -2.47178242, -4.0676017 , -2.66143763, -1.42912192, -1.2164651 ,
#        -7.14501987, -2.67492782, -2.47178242, -7.14501987, -1.2164651 ,
#        -4.5150244 , -1.2164651 , -7.14501987, -1.41481453, -1.64246378,
#        -4.5150244 , -4.5150244 , -1.41481453, -2.71012897, -1.64246378,
#        -2.42959807, -2.89446137, -2.47178242, -1.24495146, -2.69241199,
#        -1.2164651 , -1.2164651 , -4.65157679, -2.6279475 , -1.2164651 ,
#        -1.79134844, -4.5150244 , -1.2164651 , -4.44388581, -4.62529592,
#        -4.0676017 , -4.5150244 , -2.66143763, -1.41481453, -4.0676017 ,
#        -2.67492782, -1.40132433, -3.32568382, -2.51725697, -4.44388581,
# ...

# %% [markdown]
# ## Randomforest Testing data :

# %%
y_rfr_test_pred = rfr.predict(x_test)
y_rfr_test_pred
# Out:
# array([-3.97313718, -7.14501987, -2.47178242, -2.40196468, -1.44411435,
#        -1.40132433, -1.2164651 , -1.41481453, -7.14501987, -4.5150244 ,
#        -4.5150244 , -2.27343298, -1.83979246, -1.24495146, -4.5150244 ,
#        -1.40132433, -1.24495146, -2.67492782, -2.67492782, -4.65157679,
#        -3.00915981, -4.62529592, -7.12312525, -2.47657839, -4.5150244 ,
#        -4.5150244 , -4.5150244 , -4.5150244 , -4.44388581, -1.2164651 ,
#        -1.41481453, -2.67492782, -2.67492782, -1.42961706, -1.40132433,
#        -2.27343298, -2.0381419 , -2.67492782, -4.5150244 , -1.38740573,
#        -1.2164651 , -1.61447629, -7.14501987, -7.14501987, -7.12312525,
#        -4.42408609, -2.0381419 , -1.41481453, -1.41481453, -2.50541484,
#        -1.83979246, -4.5150244 , -1.2164651 , -2.6279475 , -4.62529592,
#        -1.42912192, -7.14501987, -1.2164651 , -1.41481453, -4.62529592,
#        -1.62796649, -2.69241199, -2.67492782, -2.66143763, -1.2164651 ,
# ...

# %% [markdown]
# ## <span style="color: #FF4500;"> 6.) EVALUATION: </span>
# <p style="padding: 10px; background-color: #000000; margin: 0; color: #FF4500; font-family: New Times Roman; font-size: 135%; text-align: center; border-radius: 5px; overflow: hidden; font-weight: 500;">
#                      STEP-6 : EVALUATION:<br>
#   EVALUATION or CHECKING THE MODEL PERFORMANCE :
# </p>
#
# <p style="text-align: center;">

# %% [markdown]
# ## <span style="color: #FF4500;"> 6.1 : Linear regression model. </span>

# %% [markdown]
# ### <span style="color: #FF4500;"> 6.1.1  : Checking the accuracy of Y prediction for the training data </span>
#
# We will be using , mean_squared_error and R*2 statistics here.

# %%
lr_train_mse = mean_squared_error(y_train,y_lr_pred_train)
lr_train_r2 = r2_score(y_train , y_lr_pred_train)

# %% [markdown]
# ### <span style="color: #FF4500;"> Checking the accuracy of Y prediction for the testing data </span>

# %%
lr_test_mse = mean_squared_error(y_test,y_lr_pred_test)
lr_test_r2 = r2_score(y_test , y_lr_pred_test)

# %%
print("The MSE values for Linear regression model of training data is  = {} and for Testing data it is = {}".format(lr_train_mse,lr_test_mse))
# Out:
# The MSE values for Linear regression model of training data is  = 1.0075362951093687 and for Testing data it is = 1.0206953660861033

# %%
print("The R*2 statistics score values for Linear regression model of training data is  = {} and for Testing data it is = {}".format(lr_train_r2,lr_test_r2))
# Out:
# The R*2 statistics score values for Linear regression model of training data is  = 0.7645051774663391 and for Testing data it is = 0.7891616188563282

# %% [markdown]
# ### <span style="color: #FF4500;"> Creating a table for the evaluation of all models. </span>

# %%
evaluation = pd.DataFrame(['Linear Regression'  , lr_train_mse, lr_test_mse,lr_train_r2,lr_test_r2]).transpose()
evaluation.columns = ['Model name','Training data MSE' , 'Testing data MSE' , 'R*2 score Training data', 'R*2 score Testing data' ]

# %% [markdown]
# ## <span style="color: #FF4500;"> 6.2 : Random Forest Model. </span>

# %% [markdown]
# ### <span style="color: #FF4500;"> 6.2.1  : Checking the accuracy of Y prediction for the training data </span>
#
# We will be using , mean_squared_error and R*2 statistics here.

# %%
rfr_train_mse = mean_squared_error(y_train,y_rfr_train_pred)
rfr_train_r2_score = r2_score(y_train,y_rfr_train_pred)

# %% [markdown]
# ### <span style="color: #FF4500;"> 6.2.2  : Checking the accuracy of Y prediction for the testing data </span>
#
# We will be using , mean_squared_error and R*2 statistics here.

# %%
rfr_test_mse = mean_squared_error(y_test,y_rfr_test_pred)
rfr_test_r2_score = r2_score(y_test,y_rfr_test_pred)

# %%
print("The MSE values for Random Forest model of training data is  = {} and for Testing data it is = {}".format(rfr_train_mse,rfr_test_mse))
# Out:
# The MSE values for Random Forest model of training data is  = 1.028227802112806 and for Testing data it is = 1.407688264904896

# %%
print("The  values for Random Forest model of training data is  = {} and for Testing data it is = {}".format(rfr_train_r2_score,rfr_test_r2_score))
# Out:
# The  values for Random Forest model of training data is  = 0.7596688824431413 and for Testing data it is = 0.7092230211002489

# %%
evaluation2 = pd.DataFrame(['Random Forest Model'  , rfr_train_mse, rfr_test_mse,rfr_train_r2_score,rfr_test_r2_score]).transpose()
evaluation2.columns = ['Model name','Training data MSE' , 'Testing data MSE' , 'R*2 score Training data', 'R*2 score Testing data' ]
evaluation2
# Out:
#             Model name Training data MSE Testing data MSE  \
# 0  Random Forest Model          1.028228         1.407688
#
#   R*2 score Training data R*2 score Testing data
# 0                0.759669               0.709223

# %% [markdown]
# ## <span style="color: #FF4500;"> 6.3 : FINAL EVALUATION. </span>

# %%
final_evaluation = pd.concat([evaluation , evaluation2],axis=0)

# %% [markdown]
# Reseting the index for the dataframe.

# %%
final_evaluation.reset_index(drop=True)
# Out:
#             Model name Training data MSE Testing data MSE  \
# 0    Linear Regression          1.007536         1.020695
# 1  Random Forest Model          1.028228         1.407688
#
#   R*2 score Training data R*2 score Testing data
# 0                0.764505               0.789162
# 1                0.759669               0.709223

# %% [markdown]
# ## <span style="color: #FF4500;"> 7.) VISUALIZATION: </span>
# <p style="padding: 10px; background-color: #000000; margin: 0; color: #FF4500; font-family: New Times Roman; font-size: 135%; text-align: center; border-radius: 5px; overflow: hidden; font-weight: 500;">
#                      STEP-7:<br>
#   VISUALIZATION :  .
# </p>
#
# <p style="text-align: center;">

# %% [markdown]
# ## <span style="color: #FF4500;"> 7.1 : Linear Regression Model. </span>

# %%
plt.figure(figsize = (5,5))
plt.scatter(x = y_train, y = y_lr_pred_train,c = "purple" ,alpha = 0.3)
z= np.polyfit(y_train,y_lr_pred_train,1)
p = np.poly1d(z)
plt.plot(y_train,p(y_train),"Darkgreen")
plt.ylabel("Predict logS")
plt.xlabel("Experimental logS")
# Out:
# Text(0.5, 0, 'Experimental logS')

# %% [markdown]
# ## <span style="color: #FF4500;"> 6.2 : Random Forest Model.</span>

# %%
plt.figure(figsize = (5,5))
plt.scatter(x = y_train, y = y_rfr_train_pred,c = "purple" ,alpha = 0.3)
z= np.polyfit(y_train,y_rfr_train_pred,1)
p = np.poly1d(z)
plt.plot(y_train,p(y_train),"Darkgreen")
plt.ylabel("Predict logS")
plt.xlabel("Experimental logS")
# Out:
# Text(0.5, 0, 'Experimental logS')

# %% [markdown]
# ## <span style="color: #FF4500;"> 7.) CONCLUSION: </span>
# <p style="padding: 10px; background-color: #000000; margin: 0; color: #FF4500; font-family: New Times Roman; font-size: 135%; text-align: center; border-radius: 5px; overflow: hidden; font-weight: 500;">
#                      STEP-7:<br>
#   FINAL CONCLUSION :  .
# </p>
#
# <p style="text-align: center;">

# %% [markdown]
# ## <span style="color: #FF4500;"> FROM THE ABOVE GRAPHS IT CAN BE CONCLUDED THAT THE LINEAR REGRESSION MODEL FITS THE DATA VERY WELL AS IT IT PASSING THROUGH ALL THE POINTS WITH MINIMUM DISTANCE WHEREAS THE RFR MODEL IS GONNA UNDERFIT THE DATA. </span>

# %% [markdown]
# ![Alt Text](https://cdn.dribbble.com/users/448124/screenshots/2177658/qq-.gif)

# %% [markdown]
# <a href="https://www.kaggle.com/code/darshanprabhu09/n5-data-visualization-using-graphs-visual-methods?scriptVersionId=134691249" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # <div style= "font-family: Times New Roman; font-weight:bold; letter-spacing: 0px; color:WHITE; font-size:120%; text-align:left;padding:3.0px; background: #FF4500; border-bottom: 8px solid WHITE" > TABLE OF CONTENTS<br><div>
#
# * [1. HISTOGRAM](#1)
# * [2. BAR CHART](#2)
# * [3. PIE CHART](#3)
# * [4. BOX-PLOT](#4)
# * [5. SCATTERPLOT](#5)
# * [6. LINE PLOT](#6)
# * [7. HORIZONTAL BAR CHART](#7)
# * [8. VIOLIN PLOT](#8)
# * [9. WORD CLOUD](#9)
# * [10. HEATMAP](#10)
# * [11. 3D SCATTER PLOT](#11)
# * [12. STACKED AREA CHART](#12)
# * [13. RADAR CHART](#13)
# * [14. TREE MAP](#14)
# * [15. POLAR PLOT](#15)
# * [16. STREAMPLOT](#16)
# * [17. NETWORK GRAPH](#17)
# * [18. SANKEY](#18)
# * [19. HEXBIN PLOT](#19)
# * [20. POLAR CONTOUR PLOT](#20)

# %% [markdown]
# # Libraries used and their definitons ...
#
# <h2> Matplotlib.pyplot </h2>
#
# matplotlib.pyplot is a collection of functions that make matplotlib work like MATLAB. Each pyplot function makes some change to a figure: e.g., creates a figure, creates a plotting area in a figure, plots some lines in a plotting area, decorates the plot with labels, etc.
#
# <h2> numpy </h2>
#
# NumPy is a library for the Python programming language, adding support for large, multi-dimensional arrays and matrices, along with a large collection of high-level mathematical functions to operate on these arrays.

# %%
#importing basic libraries essential for our code...

import matplotlib.pyplot as plt #importing matplot library using ".pyplot" used for making graphs and plots
import numpy as np # numpy is used for arrays and operations to be performed on them .

# %%
# Randomly sampled data
x = np.random.normal(0, 1, 1000)  # The code is used to generate a random number between 0 and 1,000 for x 
y = np.random.normal(0, 1, 1000)  # The code is used to generate a random number between 0 and 1,000 for y.
z = np.random.normal(0, 1, 1000)  #  The code is used to generate a random number between 0 and 1,000 for z.


labels = ['A', 'B', 'C', 'D', 'E'] # A list having a set of strings.
values = [25, 35, 28, 9 , 3] # A list having a set of Integers.

# %% [markdown]
# # <a id = "1"></a>
# # <div style= "font-family: Times New Roman; font-weight:bold; letter-spacing: 0px; color:WHITE; font-size:120%; text-align:left;padding:3.0px; background: #FF4500; border-bottom: 8px solid WHITE" > 1.Histogram :<br><div>
#
# A histogram is a graphical representation of data points organized into user-specified ranges. Similar in appearance to a bar graph, the histogram condenses a data series into an easily interpreted visual by taking many data points and grouping them into logical ranges or bins .  A histogram displays numerical data by grouping data into "bins" of equal width. Each bin is plotted as a bar whose height corresponds to how many data points are in that bin.Bins are also sometimes called "intervals", "classes", or "buckets".

# %%
# Creating a Histogram 

# plt.hist() is a function of pyplot used to create a Histogram 
plt.hist(x, bins=30)

#setting the x label as "value"
plt.xlabel('Value') 

#setting the y label to be "Frequency".
plt.ylabel('Frequency') 

#setting the title of the graph as "Histogram"
plt.title('Histogram') 

#plt.show is used to show the plotted functions above..
plt.show()

# %% [markdown]
# # <a id = "2"></a>
# # <div style= "font-family: Times New Roman; font-weight:bold; letter-spacing: 0px; color:WHITE; font-size:120%; text-align:left;padding:3.0px; background: #FF4500; border-bottom: 8px solid WHITE" > 2 - Barchart :<br><div>
#
#
# A  bar graph shows comparisons among discrete categories. One axis of the chart shows the specific categories being compared, and the other axis represents a measured value. Some bar graphs present bars clustered in groups of more than one, showing the values of more than one measured variable

# %%
# Creating a Barchart :

# plt.bar() is a function used to draw a barchart using pyplot module of matplotlib.
# Here we decided the X_axis to be "labels" and the y_axis to be "values"
plt.bar(labels, values)

#Labelling the title of x-axis as "Category".
plt.xlabel('Category')

#Labelling the y axis as "Value".
plt.ylabel('Value')

# Setting the title of the below graph to be "Bar Chart"
plt.title('Bar Chart')

# The same plt.show function used to display your graph or plot function...
plt.show()

# %% [markdown]
# # Barchart vs Histogram.
#
# <p style="padding: 10px; background-color: #000000; margin: 0; color: ORANGE; font-family: New Times Roman; font-size: 135%; text-align: center; border-radius: 5px; overflow: hidden; font-weight: 500;">
#     BAR CHART vs HISTOGRAM
# </p>
#
# <p style="text-align: center;">
#     <!-- Content related to the bar chart can be added here -->
# </p>
#
#
# Both histograms and bar charts provide a visual display using columns, and people often use the terms interchangeably. Technically, however, a histogram represents the frequency distribution of variables in a data set. A bar graph typically represents a graphical comparison of discrete or categorical variables.

# %% [markdown]
# # <a id = "3"></a>
# # <div style= "font-family: Times New Roman; font-weight:bold; letter-spacing: 0px; color:WHITE; font-size:120%; text-align:left;padding:3.0px; background: #FF4500; border-bottom: 8px solid WHITE" > 3 - PieChart :<br><div>
#
#
# A pie chart, sometimes called a circle chart, is a way of summarizing a set of nominal data or displaying the different values of a given variable (e.g. percentage distribution). This type of chart is a circle divided into a series of segments. Each segment represents a particular category

# %%
# A pie chart is created using plt.pie() function in pyplot.
# In the below statetment we declared values from the list of "values" and choses the list of "labels" to label them.
plt.pie(values, labels=labels)

# We use plt.title to set the label of any particular graph..
plt.title('A Pie or a Circular Chart')

# plt.show is used for displaying the graph.
plt.show()

# %% [markdown]
# # <a id = "4"></a>
# # <div style= "font-family: Times New Roman; font-weight:bold; letter-spacing: 0px; color:WHITE; font-size:120%; text-align:left;padding:3.0px; background: #FF4500; border-bottom: 8px solid WHITE" > 4 - Box-Plot :<br><div>
#
# A boxplot is a standardized way of displaying the distribution of data based on a five number summary (“minimum”, first quartile [Q1], median, third quartile [Q3] and “maximum”). It can tell you about your outliers and what their values are. Boxplots can also tell you if your data is symmetrical, how tightly your data is grouped and if and how your data is skewed.

# %%
# plt.boxplot() is a function used to initialize a boxplot with three variables as x and y
plt.boxplot([x, y])

# Labelling X-axis to be "Variable".
plt.xlabel('Variable')

# Labelling the Y-axis as "Value"
plt.ylabel('Value')

#Label the title of graph as "Box Plot".
plt.title('Box Plot')

#Last but not Least the plt.show() to display your graph
plt.show()

# %% [markdown]
# # <a id = "5"></a>
# # <div style= "font-family: Times New Roman; font-weight:bold; letter-spacing: 0px; color:WHITE; font-size:120%; text-align:left;padding:3.0px; background: #FF4500; border-bottom: 8px solid WHITE" > 5 - Scatterplot:<br><div>
# Scatter plots are the graphs that present the relationship between two variables in a data-set. It represents data points on a two-dimensional plane or on a Cartesian system. The independent variable or attribute is plotted on the X-axis, while the dependent variable is plotted on the Y-axis. These plots are often called scatter graphs or scatter diagrams.

# %%
# use plt.scatter( ) to display a scatterplot.
plt.scatter(x, y)

# Plot the label of X-axis as "X".
plt.xlabel('X')

# Plot the label of Y-axis as "Y"
plt.ylabel('Y')

#Label the Title of graph as "Scatter Plot".
plt.title('Scatter Plot')

# Using plt.show() to display the graph AGAIN...
plt.show()

# %% [markdown]
# # <a id = "6"></a>
# # <div style= "font-family: Times New Roman; font-weight:bold; letter-spacing: 0px; color:WHITE; font-size:120%; text-align:left;padding:3.0px; background: #FF4500; border-bottom: 8px solid WHITE" > 6 - Lineplot :<br><div>
#
# What is a Line Plot? A Line plot can be defined as a graph that displays data as points or check marks above a number line, showing the frequency of each value. Here, for instance, the line plot shows the number of ribbons of each length. Fun Facts. – A line plot is often confused with a line graph.

# %%
# plt.plot() is a basic function used to plot a lineplot with variables x for X-axis and y for Y-axis.
plt.plot(x, y)

#plot the X axis as "X"
plt.xlabel('X')

# Set label of Y axis as "Y".
plt.ylabel('Y')

# set the graph title to be "Line Plot"
plt.title('Line Plot')

# Display the graph
plt.show()

# %% [markdown]
# .2 LINEPLOT FOR BETTER UNDERSTANDING :

# %%
import matplotlib.pyplot as plt

# Sample data
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# Create the line plot
plt.plot(x, y)

# Set labels and title
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Line Plot")

# Display the plot
plt.show()

# %% [markdown]
# # <a id = "7"></a>
# # <div style= "font-family: Times New Roman; font-weight:bold; letter-spacing: 0px; color:WHITE; font-size:120%; text-align:left;padding:3.0px; background: #FF4500; border-bottom: 8px solid WHITE" > 7 - Horizontal Bar plot : :<br><div>
#
#
# A horizontal bar plot is a plot that presents quantitative data with rectangular bars with lengths proportional to the values that they represent. A bar plot shows comparisons among discrete categories. One axis of the plot shows the specific categories being compared, and the other axis represents a measured value.

# %%
# plt.barh() is used to plot a horizontal Barchart.
plt.barh(labels, values)

# set the X-axis label to be "Value".
plt.xlabel('Value')

# Set the Y-axis label to be "Category"
plt.ylabel('Category')

# Set the title of graph as "Horizontal Bar PLot"
plt.title('Horizontal Bar Plot')

# Display the Graph.
plt.show()

# %% [markdown]
# # <a id = "8"></a>
# # <div style= "font-family: Times New Roman; font-weight:bold; letter-spacing: 0px; color:WHITE; font-size:120%; text-align:left;padding:3.0px; background: #FF4500; border-bottom: 8px solid WHITE" > 8 - Violin Plot :<br><div>
#
# A violin plot is a hybrid of a box plot and a kernel density plot, which shows peaks in the data. It is used to visualize the distribution of numerical data. Unlike a box plot that can only show summary statistics, violin plots depict summary statistics and the density of each variable.

# %%
# plt.violinplot() is used to plot a Violin plot . Here with two variables [x,y]
plt.violinplot([x, y])

# Set the label of X-axis as "Variable"
plt.xlabel('Variable')

#Set the label of Y-axis to be "Value"
plt.ylabel('Value')

# Set the title of the Graph as "Violin Plot"
plt.title('Violin Plot')

# plt.show is used to display the Graph.
plt.show()

# %% [markdown]
# # <a id = "9"></a>
# # <div style= "font-family: Times New Roman; font-weight:bold; letter-spacing: 0px; color:WHITE; font-size:120%; text-align:left;padding:3.0px; background: #FF4500; border-bottom: 8px solid WHITE" > 9 - WordCloud:<br><div>
#
#
#
# A word cloud is a visual representation of text data where the size of each word corresponds to its frequency or importance within the text. It is a popular data visualization technique used to quickly grasp the key themes, keywords, or trends present in a body of text. Word clouds provide an intuitive and visually appealing way to highlight the most prominent words in a text corpus.

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# Sample data (replace with your own data)
text = "data analytics visualization machine learning python kaggle data science"

# Generate word cloud
wordcloud = WordCloud(width=800, height=400, background_color="white").generate(text)

# Create and configure the plot
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")

# Add a title
plt.title("Word Cloud")

# Display the plot
plt.show()

# %% [markdown]
# # <a id = "10"></a>
# # <div style= "font-family: Times New Roman; font-weight:bold; letter-spacing: 0px; color:WHITE; font-size:120%; text-align:left;padding:3.0px; background: #FF4500; border-bottom: 8px solid WHITE" > 10 - Heatmap:<br><div>
#
# A heatmap is a graphical representation of data where values in a matrix are represented as colors. It is commonly used to visualize the magnitude or density of a variable across different categories or dimensions. Heatmaps are particularly useful for identifying patterns, correlations, and trends in data by visually highlighting areas of higher or lower values with distinct color gradients.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate random data
data = np.random.rand(5, 5)

# Create a heatmap
plt.imshow(data, cmap='hot', interpolation='nearest')

# Add colorbar
plt.colorbar()

# Add title
plt.title('Heatmap')

# Display the plot
plt.show()

# %% [markdown]
# # <a id = "11"></a>
# # <div style= "font-family: Times New Roman; font-weight:bold; letter-spacing: 0px; color:WHITE; font-size:120%; text-align:left;padding:3.0px; background: #FF4500; border-bottom: 8px solid WHITE" > 11 - 3D_Scatterplot:<br><div>
#
# A 3D scatter plot is a type of visualization that represents data points in a three-dimensional space. It is used to explore relationships between three numerical variables. In a 3D scatter plot, each data point is plotted using three coordinates (x, y, z) on a three-dimensional Cartesian plane.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate random data
x = np.random.randn(100)
y = np.random.randn(100)
z = np.random.randn(100)

# Create a 3D scatter plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x, y, z)

# Add labels and title
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_zlabel('Z-axis')
ax.set_title('3D Scatter Plot')

# Display the plot
plt.show()

# %% [markdown]
# # <a id = "12"></a>
# # <div style= "font-family: Times New Roman; font-weight:bold; letter-spacing: 0px; color:WHITE; font-size:120%; text-align:left;padding:3.0px; background: #FF4500; border-bottom: 8px solid WHITE" > 12 - Stacked Area Plot:<br><div>
#
# A stacked area plot is a type of visualization that displays the cumulative contribution of multiple variables over a continuous axis, typically represented as a line or an area chart. In a stacked area plot, each variable's value is stacked on top of the previous variable, creating a cumulative representation of their combined contribution.

# %%
import matplotlib.pyplot as plt

# Data
years = [2010, 2011, 2012, 2013, 2014, 2015]
income = [25000, 35000, 45000, 55000, 50000, 60000]
expenses = [22000, 28000, 35000, 40000, 42000, 50000]

# Create a stacked area plot
plt.stackplot(years, income, expenses, labels=['Income', 'Expenses'])

# Add labels and title
plt.xlabel('Years')
plt.ylabel('Amount')
plt.title('Stacked Area Plot')

# Add legend
plt.legend()

# Display the plot
plt.show()

# %% [markdown]
# # <a id = "13"></a>
# # <div style= "font-family: Times New Roman; font-weight:bold; letter-spacing: 0px; color:WHITE; font-size:120%; text-align:left;padding:3.0px; background: #FF4500; border-bottom: 8px solid WHITE" > 13 - Radar Chart:<br><div>
#
#
# A radar chart, also known as a spider chart or a star plot, is a graphical representation that displays multivariate data on a two-dimensional polar coordinate system. It is primarily used to compare and visualize the relative values of multiple quantitative variables.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
categories = ['A', 'B', 'C', 'D', 'E']
values = [4, 2, 5, 3, 1]

# Create a radar chart
fig, ax = plt.subplots(figsize=(6, 6), subplot_kw=dict(polar=True))
ax.plot(np.linspace(0, 2 * np.pi, len(categories), endpoint=False), values)
ax.fill(np.linspace(0, 2 * np.pi, len(categories), endpoint=False), values, alpha=0.25)

# Set category labels
ax.set_xticks(np.linspace(0, 2 * np.pi, len(categories), endpoint=False))
ax.set_xticklabels(categories)

# Add title
plt.title('Radar Chart')

# Display the plot
plt.show()

# %% [markdown]
# # <a id = "14"></a>
# # <div style= "font-family: Times New Roman; font-weight:bold; letter-spacing: 0px; color:WHITE; font-size:120%; text-align:left;padding:3.0px; background: #FF4500; border-bottom: 8px solid WHITE" > 14 - Tree Map:<br><div>
# A treemap is a visualization technique used to display hierarchical data as a set of nested rectangles. Each rectangle represents a category or node in the hierarchy, and its size is proportional to a specific attribute or value associated with that category. The treemap layout utilizes the area of the rectangles to convey the relative importance or quantity of each category.

# %%
import matplotlib.pyplot as plt
import squarify

# Data
sizes = [50, 25, 15, 10]
labels = ['A', 'B', 'C', 'D']

# Create a treemap
squarify.plot(sizes=sizes, label=labels, alpha=0.7)

# Add title
plt.title('Treemap')

# Display the plot
plt.axis('off')
plt.show()

# %% [markdown]
# # <a id = "15"></a>
# # <div style= "font-family: Times New Roman; font-weight:bold; letter-spacing: 0px; color:WHITE; font-size:120%; text-align:left;padding:3.0px; background: #FF4500; border-bottom: 8px solid WHITE" > 15 - Polar Plot:<br><div>
#
#
# A polar plot, also known as a polar coordinate plot, is a type of graph that uses polar coordinates to represent data points in a circular or polar coordinate system. It is particularly useful for visualizing data that is inherently angular or periodic in nature.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
theta = np.linspace(0, 2 * np.pi, 8, endpoint=False)
radii = [2, 4, 6, 8, 10, 8, 6, 4]

# Create a polar plot
plt.polar(theta, radii)

# Add title
plt.title('Polar Plot')

# Display the plot
plt.show()

# %% [markdown]
# # <a id = "16"></a>
# # <div style= "font-family: Times New Roman; font-weight:bold; letter-spacing: 0px; color:WHITE; font-size:120%; text-align:left;padding:3.0px; background: #FF4500; border-bottom: 8px solid WHITE" > 16 - Stream Plot:<br><div>
# A stream plot, also known as a streamline plot or vector field plot, is a type of visualization that depicts the flow or movement of particles in a vector field. It is particularly useful for visualizing fluid dynamics, electromagnetic fields, and other continuous vector fields.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate random data
x = np.linspace(-3, 3, 100)
y = np.linspace(-3, 3, 100)
X, Y = np.meshgrid(x, y)
U = -1 - X**2 + Y
V = 1 + X - Y**2

# Create a streamplot
plt.streamplot(X, Y, U, V)

# Add title
plt.title('Streamplot')

# Display the plot
plt.show()

# %% [markdown]
# # <a id = "17"></a>
# # <div style= "font-family: Times New Roman; font-weight:bold; letter-spacing: 0px; color:WHITE; font-size:120%; text-align:left;padding:3.0px; background: #FF4500; border-bottom: 8px solid WHITE" > 17 - Network Graph:<br><div>
# A network graph, also known as a network diagram or graph, is a visual representation of interconnected nodes or entities, often referred to as vertices, and the connections or relationships between them, known as edges. It is used to analyze and visualize complex relationships, networks, and systems.

# %%
import matplotlib.pyplot as plt
import networkx as nx

# Create an empty graph
G = nx.Graph()

# Add nodes
G.add_nodes_from([1, 2, 3, 4, 5])

# Add edges
G.add_edges_from([(1, 2), (1, 3), (2, 3), (3, 4), (4, 5), (5, 1)])

# Create a network graph
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True)

# Add title
plt.title('Network Graph')

# Display the plot
plt.show()

# %% [markdown]
# # <a id = "18"></a>
# # <div style= "font-family: Times New Roman; font-weight:bold; letter-spacing: 0px; color:WHITE; font-size:120%; text-align:left;padding:3.0px; background: #FF4500; border-bottom: 8px solid WHITE" > 18 - Sankey plot:<br><div>
#
# A Sankey plot, also known as a Sankey diagram or flow diagram, is a type of visualization that illustrates the flow of energy, resources, or any other quantity through a system. It depicts the movement or transfer of entities between different stages or categories in a visually intuitive and proportional manner.

# %%
import matplotlib.pyplot as plt
from matplotlib.sankey import Sankey

# Create a Sankey diagram
sankey = Sankey()
sankey.add(flows=[0.25, 0.15, 0.4, -0.3, -0.1, -0.1, -0.15],
            labels=['Input 1', 'Input 2', 'Input 3', 'Output 1', 'Output 2', 'Output 3', 'Output 4'])
sankey.finish()

# Add title
plt.title('Sankey Diagram')

# Display the plot
plt.show()

# %% [markdown]
# # <a id = "19"></a>
# # <div style= "font-family: Times New Roman; font-weight:bold; letter-spacing: 0px; color:WHITE; font-size:120%; text-align:left;padding:3.0px; background: #FF4500; border-bottom: 8px solid WHITE" > 19 - Hexbin plot:<br><div>
#
# A hexbin plot is a type of two-dimensional histogram that represents the distribution of data points in a scatter plot using hexagonal bins. It is particularly useful when dealing with a large number of data points and allows for the visualization of the density and pattern of points in a more concise manner.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate random data
x = np.random.randn(1000)
y = np.random.randn(1000)

# Create a hexbin plot
plt.hexbin(x, y, gridsize=20, cmap='Blues')

# Add colorbar
plt.colorbar()

# Add title
plt.title('Hexbin Plot')

# Display the plot
plt.show()

# %% [markdown]
# # <a id = "20"></a>
# # <div style= "font-family: Times New Roman; font-weight:bold; letter-spacing: 0px; color:WHITE; font-size:120%; text-align:left;padding:3.0px; background: #FF4500; border-bottom: 8px solid WHITE" > 20 - Polar Contour Plot:<br><div>
# A polar contour plot is a type of visualization that combines the polar coordinate system with contour lines to represent three-dimensional data. It is used to display data that varies over both the angular and radial dimensions.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate random data
theta = np.linspace(0, 2 * np.pi, 100)
r = np.linspace(0, 1, 100)
Theta, R = np.meshgrid(theta, r)
Z = np.sqrt(R)

# Create a polar contour plot
plt.contourf(Theta, R, Z, cmap='viridis')

# Add colorbar
plt.colorbar()

# Add title
plt.title('Polar Contour Plot')

# Display the plot
plt.show()

# %% [markdown]
# <p style="padding: 10px; background-color: #000000; margin: 0; color: ORANGE; font-family: New Times Roman; font-size: 135%; text-align: center; border-radius: 5px; overflow: hidden; font-weight: 500;">
# Thank you and a small request :
# </p>
#
# <p style="text-align: center;">
#     <!-- Content related to the bar chart can be added here -->
# </p>
#
#
#
#
# 🙏🌟 Thank you, Kaggle Community, for your continuous support and engagement! 🌟🙏
#
# I would like to express my heartfelt gratitude to each and every one of you who has shown interest, contributed, and participated in the discussions. Your involvement has made our community vibrant and knowledge-rich.
#
# ✨ Today, I kindly request your support through upvotes and encouragement for the valuable content we share. Your upvotes serve as a testament to the relevance and quality of the discussions, allowing us to reach a wider audience and make an even greater impact.
#
# 🚀 Together, let's foster an inclusive and collaborative environment where knowledge thrives. Your support is greatly appreciated!
#
# Please consider giving an upvote if you found the content helpful or engaging. Thank you once again for being a part of our amazing Kaggle community! 🎉

# %%
import matplotlib.pyplot as plt


# Plotting an empty line to create space for the text
plt.plot([], [])

# Adding the "Thank You" text at coordinates (0.5, 0.5) in the plot
plt.text(0.5, 0.5, "Thank You  ", fontsize=20, ha='center', va='center')

# Setting the plot limits
plt.xlim(0, 1)
plt.ylim(0, 1)

# Removing the axes and ticks
plt.axis('off')

# Display the plot
plt.show()

# %% [markdown]
# ![Alt Text](https://media.giphy.com/media/vFKqnCdLPNOKc/giphy.gif)
